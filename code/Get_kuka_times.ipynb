# %%
from netCDF4 import Dataset
import datetime
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np
from scipy.signal import argrelextrema
import pickle
import warnings
import kuka_tools as kt

# %%
directory = '../data/ncs'

pits = {}

# %%
pits
# Out:
# {}

# %% [markdown]
# # 15 Jun

# %%
ka_f = 'kuka_stare_decon_Ka-Scat20230615-175713.nc'

kt.plot_file(ka_f,'ka',directory=directory,)

ku_f = 'kuka_stare_decon_Ku-Scat20230615-175508.nc'

kt.plot_file(ku_f,'ku',directory=directory)
# Out:
# []

# %%
pitno='15_Jun'
pits[pitno] = {}
pits[pitno]['ka'] = (17,57,15)
pits[pitno]['ku'] = (17,55,10)
pits[pitno]['ku_file'] = ku_f
pits[pitno]['ka_file'] = ka_f

# %%
f = 'kuka_stare_decon_Ka-Scat20230815-141405.nc'

plot_file(f,'ka')

f = 'kuka_stare_decon_Ku-Scat20230815-141405.nc'

plot_file(f,'ku')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 f = 'kuka_stare_decon_Ka-Scat20230815-141405.nc'
# ----> 3 plot_file(f,'ka')
#       5 f = 'kuka_stare_decon_Ku-Scat20230815-141405.nc'
#       7 plot_file(f,'ku')
#
# NameError: name 'plot_file' is not defined

# %%
pitno=2
pits[pitno] = {}
pits[pitno]['ka'] = ((14,14,5),(14,14,10))
pits[pitno]['ku'] = ((14,14,42),(14,14,47))
pits[pitno]['file'] = f

# %% [markdown]
# # 3rd August

# %%
ka_f = 'kuka_stare_decon_Ka-Scat20230803-133042.nc'

kt.plot_file(ka_f,'ka',directory=directory,)

ku_f = 'kuka_stare_decon_Ku-Scat20230803-133401.nc'

kt.plot_file(ku_f,'ku',directory=directory)
# Out:
# []

# %%
pitno='3_Aug'
pits[pitno] = {}
pits[pitno]['ka'] = (13,30,55)
pits[pitno]['ku'] = (13,34,29)
pits[pitno]['ku_file'] = ku_f
pits[pitno]['ka_file'] = ka_f

# %% [markdown]
# # 16th August

# %%
ka_f = 'kuka_stare_decon_Ka-Scat20230816-174736.nc'

kt.plot_file(ka_f,'ka',directory=directory,)

ku_f = 'kuka_stare_decon_Ku-Scat20230816-174921.nc'

kt.plot_file(ku_f,'ku',directory=directory)
# Out:
# []

# %%
pitno='16_Aug'
pits[pitno] = {}
pits[pitno]['ka'] = (17,47,40)
pits[pitno]['ku'] = (17,49,30)
pits[pitno]['ku_file'] = ku_f
pits[pitno]['ka_file'] = ka_f

# %%
pits
# Out:
# {'15_Jun': {'ka': (17, 57, 15),
#   'ku': (17, 55, 10),
#   'ku_file': 'kuka_stare_decon_Ku-Scat20230615-175508.nc',
#   'ka_file': 'kuka_stare_decon_Ka-Scat20230615-175713.nc'},
#  '3_Aug': {'ka': (13, 30, 55),
#   'ku': (13, 34, 29),
#   'ku_file': 'kuka_stare_decon_Ku-Scat20230803-133401.nc',
#   'ka_file': 'kuka_stare_decon_Ka-Scat20230803-133042.nc'},
#  '16_Aug': {'ka': (17, 47, 40),
#   'ku': (17, 49, 30),
#   'ku_file': 'kuka_stare_decon_Ku-Scat20230816-174921.nc',
#   'ka_file': 'kuka_stare_decon_Ka-Scat20230816-174736.nc'}}

# %% [markdown]
# # 24th August

# %%
ka_f = 'kuka_stare_decon_Ka-Scat20230824-124647.nc'

kt.plot_file(ka_f,'ka',directory=directory,)

ku_f = 'kuka_stare_decon_Ku-Scat20230824-124647.nc'

kt.plot_file(ku_f,'ku',directory=directory)
# Out:
# []

# %%
pitno='24_Aug'
pits[pitno] = {}
pits[pitno]['ka'] = (12,46,48)
pits[pitno]['ku'] = (12,48,51)
pits[pitno]['ku_file'] = ku_f
pits[pitno]['ka_file'] = ka_f

# %%
pits
# Out:
# {'15_Jun': {'ka': (17, 57, 15),
#   'ku': (17, 55, 10),
#   'ku_file': 'kuka_stare_decon_Ku-Scat20230615-175508.nc',
#   'ka_file': 'kuka_stare_decon_Ka-Scat20230615-175713.nc'},
#  '3_Aug': {'ka': (13, 30, 55),
#   'ku': (13, 34, 29),
#   'ku_file': 'kuka_stare_decon_Ku-Scat20230803-133401.nc',
#   'ka_file': 'kuka_stare_decon_Ka-Scat20230803-133042.nc'},
#  '16_Aug': {'ka': (17, 47, 40),
#   'ku': (17, 49, 30),
#   'ku_file': 'kuka_stare_decon_Ku-Scat20230816-174921.nc',
#   'ka_file': 'kuka_stare_decon_Ka-Scat20230816-174736.nc'},
#  '24_Aug': {'ka': (12, 46, 48),
#   'ku': (12, 48, 51),
#   'ku_file': 'kuka_stare_decon_Ku-Scat20230824-124647.nc',
#   'ka_file': 'kuka_stare_decon_Ka-Scat20230824-124647.nc'}}

# %% [markdown]
# # 14th September

# %%
ka_f = 'kuka_stare_decon_Ka-Scat20230914-203137.nc'

kt.plot_file(ka_f,'ka',directory=directory,)

ku_f = 'kuka_stare_decon_Ku-Scat20230914-202921.nc'

kt.plot_file(ku_f,'ku',directory=directory)
# Out:
# []

# %%
pitno='14_Sep'
pits[pitno] = {}
pits[pitno]['ka'] = (20,31,40)
pits[pitno]['ku'] = (20,29,25)
pits[pitno]['ku_file'] = ku_f
pits[pitno]['ka_file'] = ka_f

# %%
pits
# Out:
# {'15_Jun': {'ka': (17, 57, 15),
#   'ku': (17, 55, 10),
#   'ku_file': 'kuka_stare_decon_Ku-Scat20230615-175508.nc',
#   'ka_file': 'kuka_stare_decon_Ka-Scat20230615-175713.nc'},
#  '3_Aug': {'ka': (13, 30, 55),
#   'ku': (13, 34, 29),
#   'ku_file': 'kuka_stare_decon_Ku-Scat20230803-133401.nc',
#   'ka_file': 'kuka_stare_decon_Ka-Scat20230803-133042.nc'},
#  '16_Aug': {'ka': (17, 47, 40),
#   'ku': (17, 49, 30),
#   'ku_file': 'kuka_stare_decon_Ku-Scat20230816-174921.nc',
#   'ka_file': 'kuka_stare_decon_Ka-Scat20230816-174736.nc'},
#  '24_Aug': {'ka': (12, 46, 48),
#   'ku': (12, 48, 51),
#   'ku_file': 'kuka_stare_decon_Ku-Scat20230824-124647.nc',
#   'ka_file': 'kuka_stare_decon_Ka-Scat20230824-124647.nc'},
#  '14_Sep': {'ka': (20, 31, 40),
#   'ku': (20, 29, 25),
#   'ku_file': 'kuka_stare_decon_Ku-Scat20230914-202921.nc',
#   'ka_file': 'kuka_stare_decon_Ka-Scat20230914-203137.nc'}}

# %% [markdown]
# # 8th October

# %%
ka_f = 'kuka_stare_decon_Ka-Scat20231008-172423.nc'

kt.plot_file(ka_f,'ka',directory=directory,)

ku_f = 'kuka_stare_decon_Ku-Scat20231008-170241.nc'

kt.plot_file(ku_f,'ku',directory=directory)
# Out:
# []

# %%
pitno='8_Oct'
pits[pitno] = {}
pits[pitno]['ka'] = (17,24,25)
pits[pitno]['ku'] = (17,3,40)
pits[pitno]['ku_file'] = ku_f
pits[pitno]['ka_file'] = ka_f

# %%
pits
# Out:
# {'15_Jun': {'ka': (17, 57, 15),
#   'ku': (17, 55, 10),
#   'ku_file': 'kuka_stare_decon_Ku-Scat20230615-175508.nc',
#   'ka_file': 'kuka_stare_decon_Ka-Scat20230615-175713.nc'},
#  '3_Aug': {'ka': (13, 30, 55),
#   'ku': (13, 34, 29),
#   'ku_file': 'kuka_stare_decon_Ku-Scat20230803-133401.nc',
#   'ka_file': 'kuka_stare_decon_Ka-Scat20230803-133042.nc'},
#  '16_Aug': {'ka': (17, 47, 40),
#   'ku': (17, 49, 30),
#   'ku_file': 'kuka_stare_decon_Ku-Scat20230816-174921.nc',
#   'ka_file': 'kuka_stare_decon_Ka-Scat20230816-174736.nc'},
#  '24_Aug': {'ka': (12, 46, 48),
#   'ku': (12, 48, 51),
#   'ku_file': 'kuka_stare_decon_Ku-Scat20230824-124647.nc',
#   'ka_file': 'kuka_stare_decon_Ka-Scat20230824-124647.nc'},
#  '14_Sep': {'ka': (20, 31, 40),
#   'ku': (20, 29, 25),
#   'ku_file': 'kuka_stare_decon_Ku-Scat20230914-202921.nc',
#   'ka_file': 'kuka_stare_decon_Ka-Scat20230914-203137.nc'},
#  '8_Oct': {'ka': (17, 24, 25),
#   'ku': (17, 3, 40),
#   'ku_file': 'kuka_stare_decon_Ku-Scat20231008-170241.nc',
#   'ka_file': 'kuka_stare_decon_Ka-Scat20231008-172423.nc'}}

# %% [markdown]
# # Extract Waveforms

# %%
pits
# Out:
# {'15_Jun': {'ka': (17, 57, 15),
#   'ku': (17, 55, 10),
#   'ku_file': 'kuka_stare_decon_Ku-Scat20230615-175508.nc',
#   'ka_file': 'kuka_stare_decon_Ka-Scat20230615-175713.nc'},
#  '3_Aug': {'ka': (13, 30, 55),
#   'ku': (13, 34, 29),
#   'ku_file': 'kuka_stare_decon_Ku-Scat20230803-133401.nc',
#   'ka_file': 'kuka_stare_decon_Ka-Scat20230803-133042.nc'},
#  '16_Aug': {'ka': (17, 47, 40),
#   'ku': (17, 49, 30),
#   'ku_file': 'kuka_stare_decon_Ku-Scat20230816-174921.nc',
#   'ka_file': 'kuka_stare_decon_Ka-Scat20230816-174736.nc'},
#  '24_Aug': {'ka': (12, 46, 48),
#   'ku': (12, 48, 51),
#   'ku_file': 'kuka_stare_decon_Ku-Scat20230824-124647.nc',
#   'ka_file': 'kuka_stare_decon_Ka-Scat20230824-124647.nc'},
#  '14_Sep': {'ka': (20, 31, 40),
#   'ku': (20, 29, 25),
#   'ku_file': 'kuka_stare_decon_Ku-Scat20230914-202921.nc',
#   'ka_file': 'kuka_stare_decon_Ka-Scat20230914-203137.nc'},
#  '8_Oct': {'ka': (17, 24, 25),
#   'ku': (17, 3, 40),
#   'ku_file': 'kuka_stare_decon_Ku-Scat20231008-170241.nc',
#   'ka_file': 'kuka_stare_decon_Ka-Scat20231008-172423.nc'}}

# %%
pols = ['hh','vv','hv','vh']

for pitno, data_dict in pits.items():

    y,m,day = kt.get_ymd_from_filename(pits[pitno]['ku_file'])
    
    for freq in ['ka','ku']:

        start_time = datetime.datetime(y,m,day,data_dict[freq][0],data_dict[freq][1],data_dict[freq][2])

        with Dataset(f'{directory}/{data_dict[f"{freq}_file"]}') as d:
            ranges = np.array(d['range'])
            times = np.array([datetime.datetime(1970,1,1)+datetime.timedelta(seconds=int(x)) for x in d['start_time']])

            start_ind = kt.get_time_index(start_time,times)
            end_ind = start_ind+5

            for pol in pols:
            
                pits[pitno][f'{freq}_{pol}'] = np.mean(np.array(d[f'{pol}_power_decon0'])[:,start_ind:start_ind+5],axis=1)
                pits[pitno][f'{freq}_range'] = ranges

for freq in ['ka','ku']:

    for h in pits.keys():
    
        data = pits[h]
    
        dic = {pol:data[f'{freq}_{pol}'] for pol in pols}
        
        wvfms = pd.DataFrame(dic)
    
        wvfms.to_csv(f'../data/waveforms/Plate_{h}_{freq}.csv')
